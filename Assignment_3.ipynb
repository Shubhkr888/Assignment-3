# %% [markdown]
# Question 1
#
# Function advantages to reduce duplicate code(Code reusability). It makes code shorter and efficient

# %% [markdown]
# Question 2
#
# When function called then it executes the code

# %% [markdown]
# Question3
#
# def functionname(argument)

# %% [markdown]
# Question 4
#
# Function is generic set of codes where function calls means to when it calls then the code inside the function executed and return value.

# %% [markdown]
# Question 5
# Variables that are defined inside a function body have a local scope, and those defined outside have a global scope. There is one global scope, and a local scope is created whenever a function is called.

# %% [markdown]
# Question 6
#
# When the execution of the function terminates (returns), the local variables are destroyed.
#
#
# def power(x,y):
#   p = x**y
#   return p
#
#
# result = power(2,3)
# print(result)

# %% [markdown]
# Question 7
#
#
# Return value is value when function calls and return output. Expression can return value.

# %% [markdown]
# Question 8
#
# If no return statement in function then it will evaluates as a NULL.

# %% [markdown]
# Question 9
#
# Inside function we can use variable locally. To make it global then use global keywords.
#
# def myfunc():
#   global x
#   x = "fantastic"
#
# myfunc()
#
# print("Python is " + x)

# %% [markdown]
# Question 10
#
# The data type of None is NoneType.

# %% [markdown]
# Question 11
#
# That import statement imports a module named areallyourpetsnamederic

# %% [markdown]
# Question 12
#
# spam.bacon()

# %% [markdown]
# Question 13
#
# Place the line of code that might cause an error in a try clause.

# %% [markdown]
# Question 14
#
#
# The try block lets you test a block of code for errors.
#
# The except block lets you handle the error.
#
# The try block will generate an exception, because x is not defined:
#
# try:
#   print(x)
# except:
#   print("An exception occurred")
#
# Since the try block raises an error, the except block will be executed.
#
# Without the try block, the program will crash and raise an error:
